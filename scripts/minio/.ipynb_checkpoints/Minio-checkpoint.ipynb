# %%
import findspark
findspark.init()
import pyspark

# %%
import pyspark.pandas as ps

# %%
from minio import Minio
from minio.error import *
import boto3
from io import BytesIO

host = 'localhost:9000'
access_key = 'minio'
secret_key = 'miniostorage'

client = Minio(host, access_key=access_key,
                    secret_key=secret_key, secure=False)

# %%
# List objects information whose names starts with "steam".
objects = client.list_objects("kafka-bucket", prefix="/topics/steam/partition=0/steam")

for obj in objects:
    print(obj.object_name)
# Out:
# topics/steam/partition=0/steam+0+0000000000.json
# topics/steam/partition=0/steam+0+0000000001.json
# topics/steam/partition=0/steam+0+0000000002.json
# topics/steam/partition=0/steam+0+0000000003.json
# topics/steam/partition=0/steam+0+0000000004.json
# topics/steam/partition=0/steam+0+0000000005.json
# topics/steam/partition=0/steam+0+0000000006.json
# topics/steam/partition=0/steam+0+0000000007.json
# topics/steam/partition=0/steam+0+0000000008.json
# topics/steam/partition=0/steam+0+0000000009.json
# topics/steam/partition=0/steam+0+0000000010.json
# topics/steam/partition=0/steam+0+0000000011.json
# topics/steam/partition=0/steam+0+0000000012.json
# topics/steam/partition=0/steam+0+0000000013.json
# topics/steam/partition=0/steam+0+0000000014.json
# topics/steam/partition=0/steam+0+0000000015.json
# topics/steam/partition=0/steam+0+0000000016.json
# topics/steam/partition=0/steam+0+0000000017.json
# topics/steam/partition=0/steam+0+0000000018.json
# topics/steam/partition=0/steam+0+0000000019.json
# topics/steam/partition=0/steam+0+0000000020.json
# topics/steam/partition=0/steam+0+0000000021.json
# topics/steam/partition=0/steam+0+0000000022.json
# topics/steam/partition=0/steam+0+0000000023.json
# topics/steam/partition=0/steam+0+0000000024.json
# topics/steam/partition=0/steam+0+0000000025.json
# topics/steam/partition=0/steam+0+0000000026.json
# topics/steam/partition=0/steam+0+0000000027.json
# topics/steam/partition=0/steam+0+0000000028.json
# topics/steam/partition=0/steam+0+0000000029.json
# topics/steam/partition=0/steam+0+0000000030.json
# topics/steam/partition=0/steam+0+0000000031.json
# topics/steam/partition=0/steam+0+0000000032.json
# topics/steam/partition=0/steam+0+0000000033.json
# topics/steam/partition=0/steam+0+0000000034.json
# topics/steam/partition=0/steam+0+0000000035.json
# topics/steam/partition=0/steam+0+0000000036.json
# topics/steam/partition=0/steam+0+0000000037.json
# topics/steam/partition=0/steam+0+0000000038.json
# topics/steam/partition=0/steam+0+0000000039.json
# topics/steam/partition=0/steam+0+0000000040.json
# topics/steam/partition=0/steam+0+0000000041.json
# topics/steam/partition=0/steam+0+0000000042.json
# topics/steam/partition=0/steam+0+0000000043.json
# topics/steam/partition=0/steam+0+0000000044.json
# topics/steam/partition=0/steam+0+0000000045.json
# topics/steam/partition=0/steam+0+0000000046.json
# topics/steam/partition=0/steam+0+0000000047.json
# topics/steam/partition=0/steam+0+0000000048.json
# topics/steam/partition=0/steam+0+0000000049.json
# topics/steam/partition=0/steam+0+0000000050.json
# topics/steam/partition=0/steam+0+0000000051.json
# topics/steam/partition=0/steam+0+0000000052.json
# topics/steam/partition=0/steam+0+0000000053.json
# topics/steam/partition=0/steam+0+0000000054.json
# topics/steam/partition=0/steam+0+0000000055.json
# topics/steam/partition=0/steam+0+0000000056.json
# topics/steam/partition=0/steam+0+0000000057.json
# topics/steam/partition=0/steam+0+0000000058.json
# topics/steam/partition=0/steam+0+0000000059.json
# topics/steam/partition=0/steam+0+0000000060.json
# topics/steam/partition=0/steam+0+0000000061.json
# topics/steam/partition=0/steam+0+0000000062.json
# topics/steam/partition=0/steam+0+0000000063.json
# topics/steam/partition=0/steam+0+0000000064.json
# topics/steam/partition=0/steam+0+0000000065.json
# topics/steam/partition=0/steam+0+0000000066.json
# topics/steam/partition=0/steam+0+0000000067.json
# topics/steam/partition=0/steam+0+0000000068.json
# topics/steam/partition=0/steam+0+0000000069.json
# topics/steam/partition=0/steam+0+0000000070.json
# topics/steam/partition=0/steam+0+0000000071.json
# topics/steam/partition=0/steam+0+0000000072.json
# topics/steam/partition=0/steam+0+0000000073.json
# topics/steam/partition=0/steam+0+0000000074.json
# topics/steam/partition=0/steam+0+0000000075.json
# topics/steam/partition=0/steam+0+0000000076.json
# topics/steam/partition=0/steam+0+0000000077.json
# topics/steam/partition=0/steam+0+0000000078.json
# topics/steam/partition=0/steam+0+0000000079.json
# topics/steam/partition=0/steam+0+0000000080.json
# topics/steam/partition=0/steam+0+0000000081.json
# topics/steam/partition=0/steam+0+0000000082.json
# topics/steam/partition=0/steam+0+0000000083.json
# topics/steam/partition=0/steam+0+0000000084.json
# topics/steam/partition=0/steam+0+0000000085.json
# topics/steam/partition=0/steam+0+0000000086.json
# topics/steam/partition=0/steam+0+0000000087.json
# topics/steam/partition=0/steam+0+0000000088.json
# topics/steam/partition=0/steam+0+0000000089.json
# topics/steam/partition=0/steam+0+0000000090.json
# topics/steam/partition=0/steam+0+0000000091.json
# topics/steam/partition=0/steam+0+0000000092.json
# topics/steam/partition=0/steam+0+0000000093.json
# topics/steam/partition=0/steam+0+0000000094.json
# topics/steam/partition=0/steam+0+0000000095.json
# topics/steam/partition=0/steam+0+0000000096.json
# topics/steam/partition=0/steam+0+0000000097.json
# topics/steam/partition=0/steam+0+0000000098.json
# topics/steam/partition=0/steam+0+0000000099.json
# topics/steam/partition=0/steam+0+0000000100.json
# topics/steam/partition=0/steam+0+0000000101.json
# topics/steam/partition=0/steam+0+0000000102.json
# topics/steam/partition=0/steam+0+0000000103.json
# topics/steam/partition=0/steam+0+0000000104.json
# topics/steam/partition=0/steam+0+0000000105.json
# topics/steam/partition=0/steam+0+0000000106.json
# topics/steam/partition=0/steam+0+0000000107.json
# topics/steam/partition=0/steam+0+0000000108.json
# topics/steam/partition=0/steam+0+0000000109.json
# topics/steam/partition=0/steam+0+0000000110.json
# topics/steam/partition=0/steam+0+0000000111.json
# topics/steam/partition=0/steam+0+0000000112.json
# topics/steam/partition=0/steam+0+0000000113.json
# topics/steam/partition=0/steam+0+0000000114.json
# topics/steam/partition=0/steam+0+0000000115.json
# topics/steam/partition=0/steam+0+0000000116.json
# topics/steam/partition=0/steam+0+0000000117.json
# topics/steam/partition=0/steam+0+0000000118.json
# topics/steam/partition=0/steam+0+0000000119.json
# topics/steam/partition=0/steam+0+0000000120.json
# topics/steam/partition=0/steam+0+0000000121.json
# topics/steam/partition=0/steam+0+0000000122.json
# topics/steam/partition=0/steam+0+0000000123.json
# topics/steam/partition=0/steam+0+0000000124.json
# topics/steam/partition=0/steam+0+0000000125.json
# topics/steam/partition=0/steam+0+0000000126.json
# topics/steam/partition=0/steam+0+0000000127.json
# topics/steam/partition=0/steam+0+0000000128.json
# topics/steam/partition=0/steam+0+0000000129.json
# topics/steam/partition=0/steam+0+0000000130.json
# topics/steam/partition=0/steam+0+0000000131.json
# topics/steam/partition=0/steam+0+0000000132.json
# topics/steam/partition=0/steam+0+0000000133.json
# topics/steam/partition=0/steam+0+0000000134.json
# topics/steam/partition=0/steam+0+0000000135.json
# topics/steam/partition=0/steam+0+0000000136.json
# topics/steam/partition=0/steam+0+0000000137.json
# topics/steam/partition=0/steam+0+0000000138.json
# topics/steam/partition=0/steam+0+0000000139.json
# topics/steam/partition=0/steam+0+0000000140.json
# topics/steam/partition=0/steam+0+0000000141.json
# topics/steam/partition=0/steam+0+0000000142.json
# topics/steam/partition=0/steam+0+0000000143.json
# topics/steam/partition=0/steam+0+0000000144.json
# topics/steam/partition=0/steam+0+0000000145.json
# topics/steam/partition=0/steam+0+0000000146.json
# topics/steam/partition=0/steam+0+0000000147.json
# topics/steam/partition=0/steam+0+0000000148.json
# topics/steam/partition=0/steam+0+0000000149.json
# topics/steam/partition=0/steam+0+0000000150.json
# topics/steam/partition=0/steam+0+0000000151.json
# topics/steam/partition=0/steam+0+0000000152.json
# topics/steam/partition=0/steam+0+0000000153.json
# topics/steam/partition=0/steam+0+0000000154.json
# topics/steam/partition=0/steam+0+0000000155.json
# topics/steam/partition=0/steam+0+0000000156.json
# topics/steam/partition=0/steam+0+0000000157.json
# topics/steam/partition=0/steam+0+0000000158.json
# topics/steam/partition=0/steam+0+0000000159.json
# topics/steam/partition=0/steam+0+0000000160.json
# topics/steam/partition=0/steam+0+0000000161.json
# topics/steam/partition=0/steam+0+0000000162.json
# topics/steam/partition=0/steam+0+0000000163.json
# topics/steam/partition=0/steam+0+0000000164.json
# topics/steam/partition=0/steam+0+0000000165.json
# topics/steam/partition=0/steam+0+0000000166.json
# topics/steam/partition=0/steam+0+0000000167.json
# topics/steam/partition=0/steam+0+0000000168.json
# topics/steam/partition=0/steam+0+0000000169.json
# topics/steam/partition=0/steam+0+0000000170.json
# topics/steam/partition=0/steam+0+0000000171.json
# topics/steam/partition=0/steam+0+0000000172.json
# topics/steam/partition=0/steam+0+0000000173.json
# topics/steam/partition=0/steam+0+0000000174.json
# topics/steam/partition=0/steam+0+0000000175.json
# topics/steam/partition=0/steam+0+0000000176.json
# topics/steam/partition=0/steam+0+0000000177.json
# topics/steam/partition=0/steam+0+0000000178.json
# topics/steam/partition=0/steam+0+0000000179.json
# topics/steam/partition=0/steam+0+0000000180.json
# topics/steam/partition=0/steam+0+0000000181.json
# topics/steam/partition=0/steam+0+0000000182.json
# topics/steam/partition=0/steam+0+0000000183.json
# topics/steam/partition=0/steam+0+0000000184.json
# topics/steam/partition=0/steam+0+0000000185.json
# topics/steam/partition=0/steam+0+0000000186.json
# topics/steam/partition=0/steam+0+0000000187.json
# topics/steam/partition=0/steam+0+0000000188.json
# topics/steam/partition=0/steam+0+0000000189.json
# topics/steam/partition=0/steam+0+0000000190.json
# topics/steam/partition=0/steam+0+0000000191.json
# topics/steam/partition=0/steam+0+0000000192.json
# topics/steam/partition=0/steam+0+0000000193.json
# topics/steam/partition=0/steam+0+0000000194.json
# topics/steam/partition=0/steam+0+0000000195.json
# topics/steam/partition=0/steam+0+0000000196.json
# topics/steam/partition=0/steam+0+0000000197.json
# topics/steam/partition=0/steam+0+0000000198.json
# topics/steam/partition=0/steam+0+0000000199.json
# topics/steam/partition=0/steam+0+0000000200.json
# topics/steam/partition=0/steam+0+0000000201.json
# topics/steam/partition=0/steam+0+0000000202.json
# topics/steam/partition=0/steam+0+0000000203.json
# topics/steam/partition=0/steam+0+0000000204.json
# topics/steam/partition=0/steam+0+0000000205.json
# topics/steam/partition=0/steam+0+0000000206.json
# topics/steam/partition=0/steam+0+0000000207.json
# topics/steam/partition=0/steam+0+0000000208.json
# topics/steam/partition=0/steam+0+0000000209.json
# topics/steam/partition=0/steam+0+0000000210.json
# topics/steam/partition=0/steam+0+0000000211.json
# topics/steam/partition=0/steam+0+0000000212.json
# topics/steam/partition=0/steam+0+0000000213.json
# topics/steam/partition=0/steam+0+0000000214.json
# topics/steam/partition=0/steam+0+0000000215.json
# topics/steam/partition=0/steam+0+0000000216.json
# topics/steam/partition=0/steam+0+0000000217.json
# topics/steam/partition=0/steam+0+0000000218.json
# topics/steam/partition=0/steam+0+0000000219.json
# topics/steam/partition=0/steam+0+0000000220.json
# topics/steam/partition=0/steam+0+0000000221.json
# topics/steam/partition=0/steam+0+0000000222.json
# topics/steam/partition=0/steam+0+0000000223.json
# topics/steam/partition=0/steam+0+0000000224.json
# topics/steam/partition=0/steam+0+0000000225.json
# topics/steam/partition=0/steam+0+0000000226.json
# topics/steam/partition=0/steam+0+0000000227.json
# topics/steam/partition=0/steam+0+0000000228.json
# topics/steam/partition=0/steam+0+0000000229.json
# topics/steam/partition=0/steam+0+0000000230.json
# topics/steam/partition=0/steam+0+0000000231.json
# topics/steam/partition=0/steam+0+0000000232.json
# topics/steam/partition=0/steam+0+0000000233.json
# topics/steam/partition=0/steam+0+0000000234.json
# topics/steam/partition=0/steam+0+0000000235.json
# topics/steam/partition=0/steam+0+0000000236.json
# topics/steam/partition=0/steam+0+0000000237.json
# topics/steam/partition=0/steam+0+0000000238.json
# topics/steam/partition=0/steam+0+0000000239.json
# topics/steam/partition=0/steam+0+0000000240.json
# topics/steam/partition=0/steam+0+0000000241.json
# topics/steam/partition=0/steam+0+0000000242.json
# topics/steam/partition=0/steam+0+0000000243.json
# topics/steam/partition=0/steam+0+0000000244.json
# topics/steam/partition=0/steam+0+0000000245.json
# topics/steam/partition=0/steam+0+0000000246.json
# topics/steam/partition=0/steam+0+0000000247.json
# topics/steam/partition=0/steam+0+0000000248.json
# topics/steam/partition=0/steam+0+0000000249.json
# topics/steam/partition=0/steam+0+0000000250.json
# topics/steam/partition=0/steam+0+0000000251.json
# topics/steam/partition=0/steam+0+0000000252.json
# topics/steam/partition=0/steam+0+0000000253.json
# topics/steam/partition=0/steam+0+0000000254.json
# topics/steam/partition=0/steam+0+0000000255.json
# topics/steam/partition=0/steam+0+0000000256.json
# topics/steam/partition=0/steam+0+0000000257.json
# topics/steam/partition=0/steam+0+0000000258.json
# topics/steam/partition=0/steam+0+0000000259.json
# topics/steam/partition=0/steam+0+0000000260.json
# topics/steam/partition=0/steam+0+0000000261.json
# topics/steam/partition=0/steam+0+0000000262.json
# topics/steam/partition=0/steam+0+0000000263.json
# topics/steam/partition=0/steam+0+0000000264.json
# topics/steam/partition=0/steam+0+0000000265.json
# topics/steam/partition=0/steam+0+0000000266.json
# topics/steam/partition=0/steam+0+0000000267.json
# topics/steam/partition=0/steam+0+0000000268.json
# topics/steam/partition=0/steam+0+0000000269.json
# topics/steam/partition=0/steam+0+0000000270.json
# topics/steam/partition=0/steam+0+0000000271.json
# topics/steam/partition=0/steam+0+0000000272.json
# topics/steam/partition=0/steam+0+0000000273.json
# topics/steam/partition=0/steam+0+0000000274.json
# topics/steam/partition=0/steam+0+0000000275.json
# topics/steam/partition=0/steam+0+0000000276.json
# topics/steam/partition=0/steam+0+0000000277.json
# topics/steam/partition=0/steam+0+0000000278.json
# topics/steam/partition=0/steam+0+0000000279.json
# topics/steam/partition=0/steam+0+0000000280.json
# topics/steam/partition=0/steam+0+0000000281.json
# topics/steam/partition=0/steam+0+0000000282.json
# topics/steam/partition=0/steam+0+0000000283.json
# topics/steam/partition=0/steam+0+0000000284.json
# topics/steam/partition=0/steam+0+0000000285.json
# topics/steam/partition=0/steam+0+0000000286.json
# topics/steam/partition=0/steam+0+0000000287.json
# topics/steam/partition=0/steam+0+0000000288.json
# topics/steam/partition=0/steam+0+0000000289.json
# topics/steam/partition=0/steam+0+0000000290.json
# topics/steam/partition=0/steam+0+0000000291.json
# topics/steam/partition=0/steam+0+0000000292.json
# topics/steam/partition=0/steam+0+0000000293.json
# topics/steam/partition=0/steam+0+0000000294.json
# topics/steam/partition=0/steam+0+0000000295.json
# topics/steam/partition=0/steam+0+0000000296.json
# topics/steam/partition=0/steam+0+0000000297.json
# topics/steam/partition=0/steam+0+0000000298.json
# topics/steam/partition=0/steam+0+0000000299.json
# topics/steam/partition=0/steam+0+0000000300.json
# topics/steam/partition=0/steam+0+0000000301.json
# topics/steam/partition=0/steam+0+0000000302.json
# topics/steam/partition=0/steam+0+0000000303.json
# topics/steam/partition=0/steam+0+0000000304.json
# topics/steam/partition=0/steam+0+0000000305.json
# topics/steam/partition=0/steam+0+0000000306.json
# topics/steam/partition=0/steam+0+0000000307.json
# topics/steam/partition=0/steam+0+0000000308.json
# topics/steam/partition=0/steam+0+0000000309.json
# topics/steam/partition=0/steam+0+0000000310.json
# topics/steam/partition=0/steam+0+0000000311.json
# topics/steam/partition=0/steam+0+0000000312.json
# topics/steam/partition=0/steam+0+0000000313.json
# topics/steam/partition=0/steam+0+0000000314.json
# topics/steam/partition=0/steam+0+0000000315.json
# topics/steam/partition=0/steam+0+0000000316.json
# topics/steam/partition=0/steam+0+0000000317.json
# topics/steam/partition=0/steam+0+0000000318.json
# topics/steam/partition=0/steam+0+0000000319.json
# topics/steam/partition=0/steam+0+0000000320.json
# topics/steam/partition=0/steam+0+0000000321.json
# topics/steam/partition=0/steam+0+0000000322.json
# topics/steam/partition=0/steam+0+0000000323.json
# topics/steam/partition=0/steam+0+0000000324.json
# topics/steam/partition=0/steam+0+0000000325.json
# topics/steam/partition=0/steam+0+0000000326.json
# topics/steam/partition=0/steam+0+0000000327.json
# topics/steam/partition=0/steam+0+0000000328.json
# topics/steam/partition=0/steam+0+0000000329.json
# topics/steam/partition=0/steam+0+0000000330.json
# topics/steam/partition=0/steam+0+0000000331.json
# topics/steam/partition=0/steam+0+0000000332.json
# topics/steam/partition=0/steam+0+0000000333.json
# topics/steam/partition=0/steam+0+0000000334.json
# topics/steam/partition=0/steam+0+0000000335.json
# topics/steam/partition=0/steam+0+0000000336.json
# topics/steam/partition=0/steam+0+0000000337.json
# topics/steam/partition=0/steam+0+0000000338.json
# topics/steam/partition=0/steam+0+0000000339.json
# topics/steam/partition=0/steam+0+0000000340.json
# topics/steam/partition=0/steam+0+0000000341.json
# topics/steam/partition=0/steam+0+0000000342.json
# topics/steam/partition=0/steam+0+0000000343.json
# topics/steam/partition=0/steam+0+0000000344.json
# topics/steam/partition=0/steam+0+0000000345.json
# topics/steam/partition=0/steam+0+0000000346.json
# topics/steam/partition=0/steam+0+0000000347.json
# topics/steam/partition=0/steam+0+0000000348.json
# topics/steam/partition=0/steam+0+0000000349.json
# topics/steam/partition=0/steam+0+0000000350.json
# topics/steam/partition=0/steam+0+0000000351.json
# topics/steam/partition=0/steam+0+0000000352.json
# topics/steam/partition=0/steam+0+0000000353.json
# topics/steam/partition=0/steam+0+0000000354.json
# topics/steam/partition=0/steam+0+0000000355.json
# topics/steam/partition=0/steam+0+0000000356.json
# topics/steam/partition=0/steam+0+0000000357.json
# topics/steam/partition=0/steam+0+0000000358.json
# topics/steam/partition=0/steam+0+0000000359.json
# topics/steam/partition=0/steam+0+0000000360.json
# topics/steam/partition=0/steam+0+0000000361.json
# topics/steam/partition=0/steam+0+0000000362.json
# topics/steam/partition=0/steam+0+0000000363.json
# topics/steam/partition=0/steam+0+0000000364.json
# topics/steam/partition=0/steam+0+0000000365.json
# topics/steam/partition=0/steam+0+0000000366.json
# topics/steam/partition=0/steam+0+0000000367.json
# topics/steam/partition=0/steam+0+0000000368.json
# topics/steam/partition=0/steam+0+0000000369.json
# topics/steam/partition=0/steam+0+0000000370.json
# topics/steam/partition=0/steam+0+0000000371.json
# topics/steam/partition=0/steam+0+0000000372.json
# topics/steam/partition=0/steam+0+0000000373.json
# topics/steam/partition=0/steam+0+0000000374.json
# topics/steam/partition=0/steam+0+0000000375.json
# topics/steam/partition=0/steam+0+0000000376.json
# topics/steam/partition=0/steam+0+0000000377.json
# topics/steam/partition=0/steam+0+0000000378.json
# topics/steam/partition=0/steam+0+0000000379.json
# topics/steam/partition=0/steam+0+0000000380.json
# topics/steam/partition=0/steam+0+0000000381.json
# topics/steam/partition=0/steam+0+0000000382.json
# topics/steam/partition=0/steam+0+0000000383.json
# topics/steam/partition=0/steam+0+0000000384.json
# topics/steam/partition=0/steam+0+0000000385.json
# topics/steam/partition=0/steam+0+0000000386.json
# topics/steam/partition=0/steam+0+0000000387.json
# topics/steam/partition=0/steam+0+0000000388.json
# topics/steam/partition=0/steam+0+0000000389.json
# topics/steam/partition=0/steam+0+0000000390.json
# topics/steam/partition=0/steam+0+0000000391.json
# topics/steam/partition=0/steam+0+0000000392.json
# topics/steam/partition=0/steam+0+0000000393.json
# topics/steam/partition=0/steam+0+0000000394.json
# topics/steam/partition=0/steam+0+0000000395.json
# topics/steam/partition=0/steam+0+0000000396.json
# topics/steam/partition=0/steam+0+0000000397.json
# topics/steam/partition=0/steam+0+0000000398.json
# topics/steam/partition=0/steam+0+0000000399.json
# topics/steam/partition=0/steam+0+0000000400.json
# topics/steam/partition=0/steam+0+0000000401.json
# topics/steam/partition=0/steam+0+0000000402.json
# topics/steam/partition=0/steam+0+0000000403.json
# topics/steam/partition=0/steam+0+0000000404.json
# topics/steam/partition=0/steam+0+0000000405.json
# topics/steam/partition=0/steam+0+0000000406.json
# topics/steam/partition=0/steam+0+0000000407.json
# topics/steam/partition=0/steam+0+0000000408.json
# topics/steam/partition=0/steam+0+0000000409.json
# topics/steam/partition=0/steam+0+0000000410.json
# topics/steam/partition=0/steam+0+0000000411.json
# topics/steam/partition=0/steam+0+0000000412.json
# topics/steam/partition=0/steam+0+0000000413.json
# topics/steam/partition=0/steam+0+0000000414.json
# topics/steam/partition=0/steam+0+0000000415.json
# topics/steam/partition=0/steam+0+0000000416.json
# topics/steam/partition=0/steam+0+0000000417.json
# topics/steam/partition=0/steam+0+0000000418.json
# topics/steam/partition=0/steam+0+0000000419.json
# topics/steam/partition=0/steam+0+0000000420.json
# topics/steam/partition=0/steam+0+0000000421.json
# topics/steam/partition=0/steam+0+0000000422.json
# topics/steam/partition=0/steam+0+0000000423.json
# topics/steam/partition=0/steam+0+0000000424.json
# topics/steam/partition=0/steam+0+0000000425.json
# topics/steam/partition=0/steam+0+0000000426.json
# topics/steam/partition=0/steam+0+0000000427.json
# topics/steam/partition=0/steam+0+0000000428.json
# topics/steam/partition=0/steam+0+0000000429.json
# topics/steam/partition=0/steam+0+0000000430.json
# topics/steam/partition=0/steam+0+0000000431.json
# topics/steam/partition=0/steam+0+0000000432.json
# topics/steam/partition=0/steam+0+0000000433.json
# topics/steam/partition=0/steam+0+0000000434.json
# topics/steam/partition=0/steam+0+0000000435.json
# topics/steam/partition=0/steam+0+0000000436.json
# topics/steam/partition=0/steam+0+0000000437.json
# topics/steam/partition=0/steam+0+0000000438.json
# topics/steam/partition=0/steam+0+0000000439.json
# topics/steam/partition=0/steam+0+0000000440.json
# topics/steam/partition=0/steam+0+0000000441.json
# topics/steam/partition=0/steam+0+0000000442.json
# topics/steam/partition=0/steam+0+0000000443.json
# topics/steam/partition=0/steam+0+0000000444.json
# topics/steam/partition=0/steam+0+0000000445.json
# topics/steam/partition=0/steam+0+0000000446.json
# topics/steam/partition=0/steam+0+0000000447.json
# topics/steam/partition=0/steam+0+0000000448.json
# topics/steam/partition=0/steam+0+0000000449.json
# topics/steam/partition=0/steam+0+0000000450.json
# topics/steam/partition=0/steam+0+0000000451.json
# topics/steam/partition=0/steam+0+0000000452.json
# topics/steam/partition=0/steam+0+0000000453.json
# topics/steam/partition=0/steam+0+0000000454.json
# topics/steam/partition=0/steam+0+0000000455.json
# topics/steam/partition=0/steam+0+0000000456.json
# topics/steam/partition=0/steam+0+0000000457.json
# topics/steam/partition=0/steam+0+0000000458.json
# topics/steam/partition=0/steam+0+0000000459.json
# topics/steam/partition=0/steam+0+0000000460.json
# topics/steam/partition=0/steam+0+0000000461.json
# topics/steam/partition=0/steam+0+0000000462.json
# topics/steam/partition=0/steam+0+0000000463.json
# topics/steam/partition=0/steam+0+0000000464.json
# topics/steam/partition=0/steam+0+0000000465.json
# topics/steam/partition=0/steam+0+0000000466.json
# topics/steam/partition=0/steam+0+0000000467.json
# topics/steam/partition=0/steam+0+0000000468.json
# topics/steam/partition=0/steam+0+0000000469.json
# topics/steam/partition=0/steam+0+0000000470.json
# topics/steam/partition=0/steam+0+0000000471.json
# topics/steam/partition=0/steam+0+0000000472.json
# topics/steam/partition=0/steam+0+0000000473.json
# topics/steam/partition=0/steam+0+0000000474.json
# topics/steam/partition=0/steam+0+0000000475.json
# topics/steam/partition=0/steam+0+0000000476.json
# topics/steam/partition=0/steam+0+0000000477.json
# topics/steam/partition=0/steam+0+0000000478.json
# topics/steam/partition=0/steam+0+0000000479.json
# topics/steam/partition=0/steam+0+0000000480.json
# topics/steam/partition=0/steam+0+0000000481.json
# topics/steam/partition=0/steam+0+0000000482.json
# topics/steam/partition=0/steam+0+0000000483.json
# topics/steam/partition=0/steam+0+0000000484.json
# topics/steam/partition=0/steam+0+0000000485.json
# topics/steam/partition=0/steam+0+0000000486.json
# topics/steam/partition=0/steam+0+0000000487.json
# topics/steam/partition=0/steam+0+0000000488.json
# topics/steam/partition=0/steam+0+0000000489.json
# topics/steam/partition=0/steam+0+0000000490.json
# topics/steam/partition=0/steam+0+0000000491.json
# topics/steam/partition=0/steam+0+0000000492.json
# topics/steam/partition=0/steam+0+0000000493.json
# topics/steam/partition=0/steam+0+0000000494.json
# topics/steam/partition=0/steam+0+0000000495.json
# topics/steam/partition=0/steam+0+0000000496.json
# topics/steam/partition=0/steam+0+0000000497.json
# topics/steam/partition=0/steam+0+0000000498.json
# topics/steam/partition=0/steam+0+0000000499.json
# topics/steam/partition=0/steam+0+0000000500.json
# topics/steam/partition=0/steam+0+0000000501.json
# topics/steam/partition=0/steam+0+0000000502.json
# topics/steam/partition=0/steam+0+0000000503.json
# topics/steam/partition=0/steam+0+0000000504.json
# topics/steam/partition=0/steam+0+0000000505.json
# topics/steam/partition=0/steam+0+0000000506.json
# topics/steam/partition=0/steam+0+0000000507.json
# topics/steam/partition=0/steam+0+0000000508.json
# topics/steam/partition=0/steam+0+0000000509.json
# topics/steam/partition=0/steam+0+0000000510.json
# topics/steam/partition=0/steam+0+0000000511.json
# topics/steam/partition=0/steam+0+0000000512.json
# topics/steam/partition=0/steam+0+0000000513.json
# topics/steam/partition=0/steam+0+0000000514.json
# topics/steam/partition=0/steam+0+0000000515.json
# topics/steam/partition=0/steam+0+0000000516.json
# topics/steam/partition=0/steam+0+0000000517.json
# topics/steam/partition=0/steam+0+0000000518.json
# topics/steam/partition=0/steam+0+0000000519.json
# topics/steam/partition=0/steam+0+0000000520.json
# topics/steam/partition=0/steam+0+0000000521.json
# topics/steam/partition=0/steam+0+0000000522.json
# topics/steam/partition=0/steam+0+0000000523.json
# topics/steam/partition=0/steam+0+0000000524.json
# topics/steam/partition=0/steam+0+0000000525.json
# topics/steam/partition=0/steam+0+0000000526.json
# topics/steam/partition=0/steam+0+0000000527.json
# topics/steam/partition=0/steam+0+0000000528.json
# topics/steam/partition=0/steam+0+0000000529.json
# topics/steam/partition=0/steam+0+0000000530.json
# topics/steam/partition=0/steam+0+0000000531.json
# topics/steam/partition=0/steam+0+0000000532.json
# topics/steam/partition=0/steam+0+0000000533.json
# topics/steam/partition=0/steam+0+0000000534.json
# topics/steam/partition=0/steam+0+0000000535.json
# topics/steam/partition=0/steam+0+0000000536.json
# topics/steam/partition=0/steam+0+0000000537.json
# topics/steam/partition=0/steam+0+0000000538.json
# topics/steam/partition=0/steam+0+0000000539.json
# topics/steam/partition=0/steam+0+0000000540.json
# topics/steam/partition=0/steam+0+0000000541.json
# topics/steam/partition=0/steam+0+0000000542.json
# topics/steam/partition=0/steam+0+0000000543.json
# topics/steam/partition=0/steam+0+0000000544.json
# topics/steam/partition=0/steam+0+0000000545.json
# topics/steam/partition=0/steam+0+0000000546.json
# topics/steam/partition=0/steam+0+0000000547.json
# topics/steam/partition=0/steam+0+0000000548.json
# topics/steam/partition=0/steam+0+0000000549.json
# topics/steam/partition=0/steam+0+0000000550.json
# topics/steam/partition=0/steam+0+0000000551.json
# topics/steam/partition=0/steam+0+0000000552.json
# topics/steam/partition=0/steam+0+0000000553.json
# topics/steam/partition=0/steam+0+0000000554.json
# topics/steam/partition=0/steam+0+0000000555.json
# topics/steam/partition=0/steam+0+0000000556.json
# topics/steam/partition=0/steam+0+0000000557.json
# topics/steam/partition=0/steam+0+0000000558.json
# topics/steam/partition=0/steam+0+0000000559.json
# topics/steam/partition=0/steam+0+0000000560.json
# topics/steam/partition=0/steam+0+0000000561.json
# topics/steam/partition=0/steam+0+0000000562.json
# topics/steam/partition=0/steam+0+0000000563.json
# topics/steam/partition=0/steam+0+0000000564.json
# topics/steam/partition=0/steam+0+0000000565.json
# topics/steam/partition=0/steam+0+0000000566.json
# topics/steam/partition=0/steam+0+0000000567.json
# topics/steam/partition=0/steam+0+0000000568.json
# topics/steam/partition=0/steam+0+0000000569.json
# topics/steam/partition=0/steam+0+0000000570.json
# topics/steam/partition=0/steam+0+0000000571.json
# topics/steam/partition=0/steam+0+0000000572.json
# topics/steam/partition=0/steam+0+0000000573.json
# topics/steam/partition=0/steam+0+0000000574.json
# topics/steam/partition=0/steam+0+0000000575.json
# topics/steam/partition=0/steam+0+0000000576.json
# topics/steam/partition=0/steam+0+0000000577.json
# topics/steam/partition=0/steam+0+0000000578.json
# topics/steam/partition=0/steam+0+0000000579.json
# topics/steam/partition=0/steam+0+0000000580.json
# topics/steam/partition=0/steam+0+0000000581.json
# topics/steam/partition=0/steam+0+0000000582.json
# topics/steam/partition=0/steam+0+0000000583.json
# topics/steam/partition=0/steam+0+0000000584.json
# topics/steam/partition=0/steam+0+0000000585.json
# topics/steam/partition=0/steam+0+0000000586.json
# topics/steam/partition=0/steam+0+0000000587.json
# topics/steam/partition=0/steam+0+0000000588.json
# topics/steam/partition=0/steam+0+0000000589.json
# topics/steam/partition=0/steam+0+0000000590.json
# topics/steam/partition=0/steam+0+0000000591.json
# topics/steam/partition=0/steam+0+0000000592.json
# topics/steam/partition=0/steam+0+0000000593.json
# topics/steam/partition=0/steam+0+0000000594.json
# topics/steam/partition=0/steam+0+0000000595.json
# topics/steam/partition=0/steam+0+0000000596.json
# topics/steam/partition=0/steam+0+0000000597.json
# topics/steam/partition=0/steam+0+0000000598.json
# topics/steam/partition=0/steam+0+0000000599.json
# topics/steam/partition=0/steam+0+0000000600.json
# topics/steam/partition=0/steam+0+0000000601.json
# topics/steam/partition=0/steam+0+0000000602.json
# topics/steam/partition=0/steam+0+0000000603.json
# topics/steam/partition=0/steam+0+0000000604.json
# topics/steam/partition=0/steam+0+0000000605.json
# topics/steam/partition=0/steam+0+0000000606.json
# topics/steam/partition=0/steam+0+0000000607.json
# topics/steam/partition=0/steam+0+0000000608.json
# topics/steam/partition=0/steam+0+0000000609.json
# topics/steam/partition=0/steam+0+0000000610.json
# topics/steam/partition=0/steam+0+0000000611.json
# topics/steam/partition=0/steam+0+0000000612.json
# topics/steam/partition=0/steam+0+0000000613.json
# topics/steam/partition=0/steam+0+0000000614.json
# topics/steam/partition=0/steam+0+0000000615.json
# topics/steam/partition=0/steam+0+0000000616.json
# topics/steam/partition=0/steam+0+0000000617.json
# topics/steam/partition=0/steam+0+0000000618.json
# topics/steam/partition=0/steam+0+0000000619.json
# topics/steam/partition=0/steam+0+0000000620.json
# topics/steam/partition=0/steam+0+0000000621.json
# topics/steam/partition=0/steam+0+0000000622.json
# topics/steam/partition=0/steam+0+0000000623.json
# topics/steam/partition=0/steam+0+0000000624.json
# topics/steam/partition=0/steam+0+0000000625.json
# topics/steam/partition=0/steam+0+0000000626.json
# topics/steam/partition=0/steam+0+0000000627.json
# topics/steam/partition=0/steam+0+0000000628.json
# topics/steam/partition=0/steam+0+0000000629.json
# topics/steam/partition=0/steam+0+0000000630.json
# topics/steam/partition=0/steam+0+0000000631.json
# topics/steam/partition=0/steam+0+0000000632.json
# topics/steam/partition=0/steam+0+0000000633.json
# topics/steam/partition=0/steam+0+0000000634.json
# topics/steam/partition=0/steam+0+0000000635.json
# topics/steam/partition=0/steam+0+0000000636.json
# topics/steam/partition=0/steam+0+0000000637.json
# topics/steam/partition=0/steam+0+0000000638.json
# topics/steam/partition=0/steam+0+0000000639.json
# topics/steam/partition=0/steam+0+0000000640.json
# topics/steam/partition=0/steam+0+0000000641.json
# topics/steam/partition=0/steam+0+0000000642.json
# topics/steam/partition=0/steam+0+0000000643.json
# topics/steam/partition=0/steam+0+0000000644.json
# topics/steam/partition=0/steam+0+0000000645.json
# topics/steam/partition=0/steam+0+0000000646.json
# topics/steam/partition=0/steam+0+0000000647.json
# topics/steam/partition=0/steam+0+0000000648.json
# topics/steam/partition=0/steam+0+0000000649.json
# topics/steam/partition=0/steam+0+0000000650.json
# topics/steam/partition=0/steam+0+0000000651.json
# topics/steam/partition=0/steam+0+0000000652.json
# topics/steam/partition=0/steam+0+0000000653.json
# topics/steam/partition=0/steam+0+0000000654.json
# topics/steam/partition=0/steam+0+0000000655.json
# topics/steam/partition=0/steam+0+0000000656.json
# topics/steam/partition=0/steam+0+0000000657.json
# topics/steam/partition=0/steam+0+0000000658.json
# topics/steam/partition=0/steam+0+0000000659.json
# topics/steam/partition=0/steam+0+0000000660.json
# topics/steam/partition=0/steam+0+0000000661.json
# topics/steam/partition=0/steam+0+0000000662.json
# topics/steam/partition=0/steam+0+0000000663.json
# topics/steam/partition=0/steam+0+0000000664.json
# topics/steam/partition=0/steam+0+0000000665.json
# topics/steam/partition=0/steam+0+0000000666.json
# topics/steam/partition=0/steam+0+0000000667.json
# topics/steam/partition=0/steam+0+0000000668.json
# topics/steam/partition=0/steam+0+0000000669.json
# topics/steam/partition=0/steam+0+0000000670.json
# topics/steam/partition=0/steam+0+0000000671.json
# topics/steam/partition=0/steam+0+0000000672.json
# topics/steam/partition=0/steam+0+0000000673.json
# topics/steam/partition=0/steam+0+0000000674.json
# topics/steam/partition=0/steam+0+0000000675.json
# topics/steam/partition=0/steam+0+0000000676.json
# topics/steam/partition=0/steam+0+0000000677.json
# topics/steam/partition=0/steam+0+0000000678.json
# topics/steam/partition=0/steam+0+0000000679.json
# topics/steam/partition=0/steam+0+0000000680.json
# topics/steam/partition=0/steam+0+0000000681.json
# topics/steam/partition=0/steam+0+0000000682.json
# topics/steam/partition=0/steam+0+0000000683.json
# topics/steam/partition=0/steam+0+0000000684.json
# topics/steam/partition=0/steam+0+0000000685.json
# topics/steam/partition=0/steam+0+0000000686.json
# topics/steam/partition=0/steam+0+0000000687.json
# topics/steam/partition=0/steam+0+0000000688.json
# topics/steam/partition=0/steam+0+0000000689.json
# topics/steam/partition=0/steam+0+0000000690.json
# topics/steam/partition=0/steam+0+0000000691.json
# topics/steam/partition=0/steam+0+0000000692.json
# topics/steam/partition=0/steam+0+0000000693.json
# topics/steam/partition=0/steam+0+0000000694.json
# topics/steam/partition=0/steam+0+0000000695.json
# topics/steam/partition=0/steam+0+0000000696.json
# topics/steam/partition=0/steam+0+0000000697.json
# topics/steam/partition=0/steam+0+0000000698.json
# topics/steam/partition=0/steam+0+0000000699.json
# topics/steam/partition=0/steam+0+0000000700.json
# topics/steam/partition=0/steam+0+0000000701.json
# topics/steam/partition=0/steam+0+0000000702.json
# topics/steam/partition=0/steam+0+0000000703.json
# topics/steam/partition=0/steam+0+0000000704.json
# topics/steam/partition=0/steam+0+0000000705.json
# topics/steam/partition=0/steam+0+0000000706.json
# topics/steam/partition=0/steam+0+0000000707.json
# topics/steam/partition=0/steam+0+0000000708.json
# topics/steam/partition=0/steam+0+0000000709.json
# topics/steam/partition=0/steam+0+0000000710.json
# topics/steam/partition=0/steam+0+0000000711.json
# topics/steam/partition=0/steam+0+0000000712.json
# topics/steam/partition=0/steam+0+0000000713.json
# topics/steam/partition=0/steam+0+0000000714.json
# topics/steam/partition=0/steam+0+0000000715.json
# topics/steam/partition=0/steam+0+0000000716.json
# topics/steam/partition=0/steam+0+0000000717.json
# topics/steam/partition=0/steam+0+0000000718.json
# topics/steam/partition=0/steam+0+0000000719.json
# topics/steam/partition=0/steam+0+0000000720.json
# topics/steam/partition=0/steam+0+0000000721.json
# topics/steam/partition=0/steam+0+0000000722.json
# topics/steam/partition=0/steam+0+0000000723.json
# topics/steam/partition=0/steam+0+0000000724.json
# topics/steam/partition=0/steam+0+0000000725.json
# topics/steam/partition=0/steam+0+0000000726.json
# topics/steam/partition=0/steam+0+0000000727.json
# topics/steam/partition=0/steam+0+0000000728.json
# topics/steam/partition=0/steam+0+0000000729.json
# topics/steam/partition=0/steam+0+0000000730.json
# topics/steam/partition=0/steam+0+0000000731.json
# topics/steam/partition=0/steam+0+0000000732.json
# topics/steam/partition=0/steam+0+0000000733.json
# topics/steam/partition=0/steam+0+0000000734.json
# topics/steam/partition=0/steam+0+0000000735.json
# topics/steam/partition=0/steam+0+0000000736.json
# topics/steam/partition=0/steam+0+0000000737.json
# topics/steam/partition=0/steam+0+0000000738.json
# topics/steam/partition=0/steam+0+0000000739.json
# topics/steam/partition=0/steam+0+0000000740.json
# topics/steam/partition=0/steam+0+0000000741.json
# topics/steam/partition=0/steam+0+0000000742.json
# topics/steam/partition=0/steam+0+0000000743.json
# topics/steam/partition=0/steam+0+0000000744.json
# topics/steam/partition=0/steam+0+0000000745.json
# topics/steam/partition=0/steam+0+0000000746.json
# topics/steam/partition=0/steam+0+0000000747.json
# topics/steam/partition=0/steam+0+0000000748.json
# topics/steam/partition=0/steam+0+0000000749.json
# topics/steam/partition=0/steam+0+0000000750.json
# topics/steam/partition=0/steam+0+0000000751.json
# topics/steam/partition=0/steam+0+0000000752.json
# topics/steam/partition=0/steam+0+0000000753.json
# topics/steam/partition=0/steam+0+0000000754.json
# topics/steam/partition=0/steam+0+0000000755.json
# topics/steam/partition=0/steam+0+0000000756.json
# topics/steam/partition=0/steam+0+0000000757.json
# topics/steam/partition=0/steam+0+0000000758.json
# topics/steam/partition=0/steam+0+0000000759.json
# topics/steam/partition=0/steam+0+0000000760.json
# topics/steam/partition=0/steam+0+0000000761.json
# topics/steam/partition=0/steam+0+0000000762.json
# topics/steam/partition=0/steam+0+0000000763.json
# topics/steam/partition=0/steam+0+0000000764.json
# topics/steam/partition=0/steam+0+0000000765.json
# topics/steam/partition=0/steam+0+0000000766.json
# topics/steam/partition=0/steam+0+0000000767.json
# topics/steam/partition=0/steam+0+0000000768.json
# topics/steam/partition=0/steam+0+0000000769.json
# topics/steam/partition=0/steam+0+0000000770.json
# topics/steam/partition=0/steam+0+0000000771.json
# topics/steam/partition=0/steam+0+0000000772.json
# topics/steam/partition=0/steam+0+0000000773.json
# topics/steam/partition=0/steam+0+0000000774.json
# topics/steam/partition=0/steam+0+0000000775.json
# topics/steam/partition=0/steam+0+0000000776.json
# topics/steam/partition=0/steam+0+0000000777.json
# topics/steam/partition=0/steam+0+0000000778.json
# topics/steam/partition=0/steam+0+0000000779.json
# topics/steam/partition=0/steam+0+0000000780.json
# topics/steam/partition=0/steam+0+0000000781.json
# topics/steam/partition=0/steam+0+0000000782.json
# topics/steam/partition=0/steam+0+0000000783.json
# topics/steam/partition=0/steam+0+0000000784.json
# topics/steam/partition=0/steam+0+0000000785.json
# topics/steam/partition=0/steam+0+0000000786.json
# topics/steam/partition=0/steam+0+0000000787.json
# topics/steam/partition=0/steam+0+0000000788.json
# topics/steam/partition=0/steam+0+0000000789.json
# topics/steam/partition=0/steam+0+0000000790.json
# topics/steam/partition=0/steam+0+0000000791.json
# topics/steam/partition=0/steam+0+0000000792.json
# topics/steam/partition=0/steam+0+0000000793.json
# topics/steam/partition=0/steam+0+0000000794.json
# topics/steam/partition=0/steam+0+0000000795.json
# topics/steam/partition=0/steam+0+0000000796.json
# topics/steam/partition=0/steam+0+0000000797.json
# topics/steam/partition=0/steam+0+0000000798.json
# topics/steam/partition=0/steam+0+0000000799.json
# topics/steam/partition=0/steam+0+0000000800.json
# topics/steam/partition=0/steam+0+0000000801.json
# topics/steam/partition=0/steam+0+0000000802.json
# topics/steam/partition=0/steam+0+0000000803.json
# topics/steam/partition=0/steam+0+0000000804.json
# topics/steam/partition=0/steam+0+0000000805.json
# topics/steam/partition=0/steam+0+0000000806.json
# topics/steam/partition=0/steam+0+0000000807.json
# topics/steam/partition=0/steam+0+0000000808.json
# topics/steam/partition=0/steam+0+0000000809.json
# topics/steam/partition=0/steam+0+0000000810.json
# topics/steam/partition=0/steam+0+0000000811.json
# topics/steam/partition=0/steam+0+0000000812.json
# topics/steam/partition=0/steam+0+0000000813.json
# topics/steam/partition=0/steam+0+0000000814.json
# topics/steam/partition=0/steam+0+0000000815.json
# topics/steam/partition=0/steam+0+0000000816.json
# topics/steam/partition=0/steam+0+0000000817.json
# topics/steam/partition=0/steam+0+0000000818.json
# topics/steam/partition=0/steam+0+0000000819.json
# topics/steam/partition=0/steam+0+0000000820.json
# topics/steam/partition=0/steam+0+0000000821.json
# topics/steam/partition=0/steam+0+0000000822.json
# topics/steam/partition=0/steam+0+0000000823.json
# topics/steam/partition=0/steam+0+0000000824.json
# topics/steam/partition=0/steam+0+0000000825.json
# topics/steam/partition=0/steam+0+0000000826.json
# topics/steam/partition=0/steam+0+0000000827.json
# topics/steam/partition=0/steam+0+0000000828.json
# topics/steam/partition=0/steam+0+0000000829.json
# topics/steam/partition=0/steam+0+0000000830.json
# topics/steam/partition=0/steam+0+0000000831.json
# topics/steam/partition=0/steam+0+0000000832.json
# topics/steam/partition=0/steam+0+0000000833.json
# topics/steam/partition=0/steam+0+0000000834.json
# topics/steam/partition=0/steam+0+0000000835.json
# topics/steam/partition=0/steam+0+0000000836.json
# topics/steam/partition=0/steam+0+0000000837.json
# topics/steam/partition=0/steam+0+0000000838.json
# topics/steam/partition=0/steam+0+0000000839.json
# topics/steam/partition=0/steam+0+0000000840.json
# topics/steam/partition=0/steam+0+0000000841.json
# topics/steam/partition=0/steam+0+0000000842.json
# topics/steam/partition=0/steam+0+0000000843.json
# topics/steam/partition=0/steam+0+0000000844.json
# topics/steam/partition=0/steam+0+0000000845.json
# topics/steam/partition=0/steam+0+0000000846.json
# topics/steam/partition=0/steam+0+0000000847.json
# topics/steam/partition=0/steam+0+0000000848.json
# topics/steam/partition=0/steam+0+0000000849.json
# topics/steam/partition=0/steam+0+0000000850.json
# topics/steam/partition=0/steam+0+0000000851.json
# topics/steam/partition=0/steam+0+0000000852.json
# topics/steam/partition=0/steam+0+0000000853.json
# topics/steam/partition=0/steam+0+0000000854.json
# topics/steam/partition=0/steam+0+0000000855.json
# topics/steam/partition=0/steam+0+0000000856.json
# topics/steam/partition=0/steam+0+0000000857.json
# topics/steam/partition=0/steam+0+0000000858.json
# topics/steam/partition=0/steam+0+0000000859.json
# topics/steam/partition=0/steam+0+0000000860.json
# topics/steam/partition=0/steam+0+0000000861.json
# topics/steam/partition=0/steam+0+0000000862.json
# topics/steam/partition=0/steam+0+0000000863.json
# topics/steam/partition=0/steam+0+0000000864.json
# topics/steam/partition=0/steam+0+0000000865.json
# topics/steam/partition=0/steam+0+0000000866.json
# topics/steam/partition=0/steam+0+0000000867.json
# topics/steam/partition=0/steam+0+0000000868.json
# topics/steam/partition=0/steam+0+0000000869.json
# topics/steam/partition=0/steam+0+0000000870.json
# topics/steam/partition=0/steam+0+0000000871.json
# topics/steam/partition=0/steam+0+0000000872.json
# topics/steam/partition=0/steam+0+0000000873.json
# topics/steam/partition=0/steam+0+0000000874.json
# topics/steam/partition=0/steam+0+0000000875.json
# topics/steam/partition=0/steam+0+0000000876.json
# topics/steam/partition=0/steam+0+0000000877.json
# topics/steam/partition=0/steam+0+0000000878.json
# topics/steam/partition=0/steam+0+0000000879.json
# topics/steam/partition=0/steam+0+0000000880.json
# topics/steam/partition=0/steam+0+0000000881.json
# topics/steam/partition=0/steam+0+0000000882.json
# topics/steam/partition=0/steam+0+0000000883.json
# topics/steam/partition=0/steam+0+0000000884.json
# topics/steam/partition=0/steam+0+0000000885.json
# topics/steam/partition=0/steam+0+0000000886.json
# topics/steam/partition=0/steam+0+0000000887.json
# topics/steam/partition=0/steam+0+0000000888.json
# topics/steam/partition=0/steam+0+0000000889.json
# topics/steam/partition=0/steam+0+0000000890.json
# topics/steam/partition=0/steam+0+0000000891.json
# topics/steam/partition=0/steam+0+0000000892.json
# topics/steam/partition=0/steam+0+0000000893.json
# topics/steam/partition=0/steam+0+0000000894.json
# topics/steam/partition=0/steam+0+0000000895.json
# topics/steam/partition=0/steam+0+0000000896.json
# topics/steam/partition=0/steam+0+0000000897.json
# topics/steam/partition=0/steam+0+0000000898.json
# topics/steam/partition=0/steam+0+0000000899.json
# topics/steam/partition=0/steam+0+0000000900.json
# topics/steam/partition=0/steam+0+0000000901.json
# topics/steam/partition=0/steam+0+0000000902.json
# topics/steam/partition=0/steam+0+0000000903.json
# topics/steam/partition=0/steam+0+0000000904.json
# topics/steam/partition=0/steam+0+0000000905.json
# topics/steam/partition=0/steam+0+0000000906.json
# topics/steam/partition=0/steam+0+0000000907.json
# topics/steam/partition=0/steam+0+0000000908.json
# topics/steam/partition=0/steam+0+0000000909.json
# topics/steam/partition=0/steam+0+0000000910.json
# topics/steam/partition=0/steam+0+0000000911.json
# topics/steam/partition=0/steam+0+0000000912.json
# topics/steam/partition=0/steam+0+0000000913.json
# topics/steam/partition=0/steam+0+0000000914.json
# topics/steam/partition=0/steam+0+0000000915.json
# topics/steam/partition=0/steam+0+0000000916.json
# topics/steam/partition=0/steam+0+0000000917.json
# topics/steam/partition=0/steam+0+0000000918.json
# topics/steam/partition=0/steam+0+0000000919.json
# topics/steam/partition=0/steam+0+0000000920.json
# topics/steam/partition=0/steam+0+0000000921.json
# topics/steam/partition=0/steam+0+0000000922.json
# topics/steam/partition=0/steam+0+0000000923.json
# topics/steam/partition=0/steam+0+0000000924.json
# topics/steam/partition=0/steam+0+0000000925.json
# topics/steam/partition=0/steam+0+0000000926.json
# topics/steam/partition=0/steam+0+0000000927.json
# topics/steam/partition=0/steam+0+0000000928.json
# topics/steam/partition=0/steam+0+0000000929.json
# topics/steam/partition=0/steam+0+0000000930.json
# topics/steam/partition=0/steam+0+0000000931.json
# topics/steam/partition=0/steam+0+0000000932.json
# topics/steam/partition=0/steam+0+0000000933.json
# topics/steam/partition=0/steam+0+0000000934.json
# topics/steam/partition=0/steam+0+0000000935.json
# topics/steam/partition=0/steam+0+0000000936.json
# topics/steam/partition=0/steam+0+0000000937.json
# topics/steam/partition=0/steam+0+0000000938.json
# topics/steam/partition=0/steam+0+0000000939.json
# topics/steam/partition=0/steam+0+0000000940.json
# topics/steam/partition=0/steam+0+0000000941.json
# topics/steam/partition=0/steam+0+0000000942.json
# topics/steam/partition=0/steam+0+0000000943.json
# topics/steam/partition=0/steam+0+0000000944.json
# topics/steam/partition=0/steam+0+0000000945.json
# topics/steam/partition=0/steam+0+0000000946.json
# topics/steam/partition=0/steam+0+0000000947.json
# topics/steam/partition=0/steam+0+0000000948.json
# topics/steam/partition=0/steam+0+0000000949.json
# topics/steam/partition=0/steam+0+0000000950.json
# topics/steam/partition=0/steam+0+0000000951.json
# topics/steam/partition=0/steam+0+0000000952.json
# topics/steam/partition=0/steam+0+0000000953.json
# topics/steam/partition=0/steam+0+0000000954.json
# topics/steam/partition=0/steam+0+0000000955.json
# topics/steam/partition=0/steam+0+0000000956.json
# topics/steam/partition=0/steam+0+0000000957.json
# topics/steam/partition=0/steam+0+0000000958.json
# topics/steam/partition=0/steam+0+0000000959.json
# topics/steam/partition=0/steam+0+0000000960.json
# topics/steam/partition=0/steam+0+0000000961.json
# topics/steam/partition=0/steam+0+0000000962.json
# topics/steam/partition=0/steam+0+0000000963.json
# topics/steam/partition=0/steam+0+0000000964.json
# topics/steam/partition=0/steam+0+0000000965.json
# topics/steam/partition=0/steam+0+0000000966.json
# topics/steam/partition=0/steam+0+0000000967.json
# topics/steam/partition=0/steam+0+0000000968.json
# topics/steam/partition=0/steam+0+0000000969.json
# topics/steam/partition=0/steam+0+0000000970.json
# topics/steam/partition=0/steam+0+0000000971.json
# topics/steam/partition=0/steam+0+0000000972.json
# topics/steam/partition=0/steam+0+0000000973.json
# topics/steam/partition=0/steam+0+0000000974.json
# topics/steam/partition=0/steam+0+0000000975.json
# topics/steam/partition=0/steam+0+0000000976.json
# topics/steam/partition=0/steam+0+0000000977.json
# topics/steam/partition=0/steam+0+0000000978.json
# ...
# topics/steam/partition=0/steam+0+0000003421.json
# topics/steam/partition=0/steam+0+0000003422.json
# topics/steam/partition=0/steam+0+0000003423.json
# topics/steam/partition=0/steam+0+0000003424.json
# topics/steam/partition=0/steam+0+0000003425.json
# topics/steam/partition=0/steam+0+0000003426.json
# topics/steam/partition=0/steam+0+0000003427.json
# topics/steam/partition=0/steam+0+0000003428.json
# topics/steam/partition=0/steam+0+0000003429.json
# topics/steam/partition=0/steam+0+0000003430.json
# topics/steam/partition=0/steam+0+0000003431.json
# topics/steam/partition=0/steam+0+0000003432.json
# topics/steam/partition=0/steam+0+0000003433.json
# topics/steam/partition=0/steam+0+0000003434.json
# topics/steam/partition=0/steam+0+0000003435.json
# topics/steam/partition=0/steam+0+0000003436.json
# topics/steam/partition=0/steam+0+0000003437.json
# topics/steam/partition=0/steam+0+0000003438.json
# topics/steam/partition=0/steam+0+0000003439.json
# topics/steam/partition=0/steam+0+0000003440.json
# topics/steam/partition=0/steam+0+0000003441.json
# topics/steam/partition=0/steam+0+0000003442.json
# topics/steam/partition=0/steam+0+0000003443.json
# topics/steam/partition=0/steam+0+0000003444.json
# topics/steam/partition=0/steam+0+0000003445.json
# topics/steam/partition=0/steam+0+0000003446.json
# topics/steam/partition=0/steam+0+0000003447.json
# topics/steam/partition=0/steam+0+0000003448.json
# topics/steam/partition=0/steam+0+0000003449.json
# topics/steam/partition=0/steam+0+0000003450.json
# topics/steam/partition=0/steam+0+0000003451.json
# topics/steam/partition=0/steam+0+0000003452.json
# topics/steam/partition=0/steam+0+0000003453.json
# topics/steam/partition=0/steam+0+0000003454.json
# topics/steam/partition=0/steam+0+0000003455.json
# topics/steam/partition=0/steam+0+0000003456.json
# topics/steam/partition=0/steam+0+0000003457.json
# topics/steam/partition=0/steam+0+0000003458.json
# topics/steam/partition=0/steam+0+0000003459.json
# topics/steam/partition=0/steam+0+0000003460.json
# topics/steam/partition=0/steam+0+0000003461.json
# topics/steam/partition=0/steam+0+0000003462.json
# topics/steam/partition=0/steam+0+0000003463.json
# topics/steam/partition=0/steam+0+0000003464.json
# topics/steam/partition=0/steam+0+0000003465.json
# topics/steam/partition=0/steam+0+0000003466.json
# topics/steam/partition=0/steam+0+0000003467.json
# topics/steam/partition=0/steam+0+0000003468.json
# topics/steam/partition=0/steam+0+0000003469.json
# topics/steam/partition=0/steam+0+0000003470.json
# topics/steam/partition=0/steam+0+0000003471.json
# topics/steam/partition=0/steam+0+0000003472.json
# topics/steam/partition=0/steam+0+0000003473.json
# topics/steam/partition=0/steam+0+0000003474.json
# topics/steam/partition=0/steam+0+0000003475.json
# topics/steam/partition=0/steam+0+0000003476.json
# topics/steam/partition=0/steam+0+0000003477.json
# topics/steam/partition=0/steam+0+0000003478.json
# topics/steam/partition=0/steam+0+0000003479.json
# topics/steam/partition=0/steam+0+0000003480.json
# topics/steam/partition=0/steam+0+0000003481.json
# topics/steam/partition=0/steam+0+0000003482.json
# topics/steam/partition=0/steam+0+0000003483.json
# topics/steam/partition=0/steam+0+0000003484.json
# topics/steam/partition=0/steam+0+0000003485.json
# topics/steam/partition=0/steam+0+0000003486.json
# topics/steam/partition=0/steam+0+0000003487.json
# topics/steam/partition=0/steam+0+0000003488.json
# topics/steam/partition=0/steam+0+0000003489.json
# topics/steam/partition=0/steam+0+0000003490.json
# topics/steam/partition=0/steam+0+0000003491.json
# topics/steam/partition=0/steam+0+0000003492.json
# topics/steam/partition=0/steam+0+0000003493.json
# topics/steam/partition=0/steam+0+0000003494.json
# topics/steam/partition=0/steam+0+0000003495.json
# topics/steam/partition=0/steam+0+0000003496.json
# topics/steam/partition=0/steam+0+0000003497.json
# topics/steam/partition=0/steam+0+0000003498.json
# topics/steam/partition=0/steam+0+0000003499.json
# topics/steam/partition=0/steam+0+0000003500.json
# topics/steam/partition=0/steam+0+0000003501.json
# topics/steam/partition=0/steam+0+0000003502.json
# topics/steam/partition=0/steam+0+0000003503.json
# topics/steam/partition=0/steam+0+0000003504.json
# topics/steam/partition=0/steam+0+0000003505.json
# topics/steam/partition=0/steam+0+0000003506.json
# topics/steam/partition=0/steam+0+0000003507.json
# topics/steam/partition=0/steam+0+0000003508.json
# topics/steam/partition=0/steam+0+0000003509.json
# topics/steam/partition=0/steam+0+0000003510.json
# topics/steam/partition=0/steam+0+0000003511.json
# topics/steam/partition=0/steam+0+0000003512.json
# topics/steam/partition=0/steam+0+0000003513.json
# topics/steam/partition=0/steam+0+0000003514.json
# topics/steam/partition=0/steam+0+0000003515.json
# topics/steam/partition=0/steam+0+0000003516.json
# topics/steam/partition=0/steam+0+0000003517.json
# topics/steam/partition=0/steam+0+0000003518.json
# topics/steam/partition=0/steam+0+0000003519.json
# topics/steam/partition=0/steam+0+0000003520.json
# topics/steam/partition=0/steam+0+0000003521.json
# topics/steam/partition=0/steam+0+0000003522.json
# topics/steam/partition=0/steam+0+0000003523.json
# topics/steam/partition=0/steam+0+0000003524.json
# topics/steam/partition=0/steam+0+0000003525.json
# topics/steam/partition=0/steam+0+0000003526.json
# topics/steam/partition=0/steam+0+0000003527.json
# topics/steam/partition=0/steam+0+0000003528.json
# topics/steam/partition=0/steam+0+0000003529.json
# topics/steam/partition=0/steam+0+0000003530.json
# topics/steam/partition=0/steam+0+0000003531.json
# topics/steam/partition=0/steam+0+0000003532.json
# topics/steam/partition=0/steam+0+0000003533.json
# topics/steam/partition=0/steam+0+0000003534.json
# topics/steam/partition=0/steam+0+0000003535.json
# topics/steam/partition=0/steam+0+0000003536.json
# topics/steam/partition=0/steam+0+0000003537.json
# topics/steam/partition=0/steam+0+0000003538.json
# topics/steam/partition=0/steam+0+0000003539.json
# topics/steam/partition=0/steam+0+0000003540.json
# topics/steam/partition=0/steam+0+0000003541.json
# topics/steam/partition=0/steam+0+0000003542.json
# topics/steam/partition=0/steam+0+0000003543.json
# topics/steam/partition=0/steam+0+0000003544.json
# topics/steam/partition=0/steam+0+0000003545.json
# topics/steam/partition=0/steam+0+0000003546.json
# topics/steam/partition=0/steam+0+0000003547.json
# topics/steam/partition=0/steam+0+0000003548.json
# topics/steam/partition=0/steam+0+0000003549.json
# topics/steam/partition=0/steam+0+0000003550.json
# topics/steam/partition=0/steam+0+0000003551.json
# topics/steam/partition=0/steam+0+0000003552.json
# topics/steam/partition=0/steam+0+0000003553.json
# topics/steam/partition=0/steam+0+0000003554.json
# topics/steam/partition=0/steam+0+0000003555.json
# topics/steam/partition=0/steam+0+0000003556.json
# topics/steam/partition=0/steam+0+0000003557.json
# topics/steam/partition=0/steam+0+0000003558.json
# topics/steam/partition=0/steam+0+0000003559.json
# topics/steam/partition=0/steam+0+0000003560.json
# topics/steam/partition=0/steam+0+0000003561.json
# topics/steam/partition=0/steam+0+0000003562.json
# topics/steam/partition=0/steam+0+0000003563.json
# topics/steam/partition=0/steam+0+0000003564.json
# topics/steam/partition=0/steam+0+0000003565.json
# topics/steam/partition=0/steam+0+0000003566.json
# topics/steam/partition=0/steam+0+0000003567.json
# topics/steam/partition=0/steam+0+0000003568.json
# topics/steam/partition=0/steam+0+0000003569.json
# topics/steam/partition=0/steam+0+0000003570.json
# topics/steam/partition=0/steam+0+0000003571.json
# topics/steam/partition=0/steam+0+0000003572.json
# topics/steam/partition=0/steam+0+0000003573.json
# topics/steam/partition=0/steam+0+0000003574.json
# topics/steam/partition=0/steam+0+0000003575.json
# topics/steam/partition=0/steam+0+0000003576.json
# topics/steam/partition=0/steam+0+0000003577.json
# topics/steam/partition=0/steam+0+0000003578.json
# topics/steam/partition=0/steam+0+0000003579.json
# topics/steam/partition=0/steam+0+0000003580.json
# topics/steam/partition=0/steam+0+0000003581.json
# topics/steam/partition=0/steam+0+0000003582.json
# topics/steam/partition=0/steam+0+0000003583.json
# topics/steam/partition=0/steam+0+0000003584.json
# topics/steam/partition=0/steam+0+0000003585.json
# topics/steam/partition=0/steam+0+0000003586.json
# topics/steam/partition=0/steam+0+0000003587.json
# topics/steam/partition=0/steam+0+0000003588.json
# topics/steam/partition=0/steam+0+0000003589.json
# topics/steam/partition=0/steam+0+0000003590.json
# topics/steam/partition=0/steam+0+0000003591.json
# topics/steam/partition=0/steam+0+0000003592.json
# topics/steam/partition=0/steam+0+0000003593.json
# topics/steam/partition=0/steam+0+0000003594.json
# topics/steam/partition=0/steam+0+0000003595.json
# topics/steam/partition=0/steam+0+0000003596.json
# topics/steam/partition=0/steam+0+0000003597.json
# topics/steam/partition=0/steam+0+0000003598.json
# topics/steam/partition=0/steam+0+0000003599.json
# topics/steam/partition=0/steam+0+0000003600.json
# topics/steam/partition=0/steam+0+0000003601.json
# topics/steam/partition=0/steam+0+0000003602.json
# topics/steam/partition=0/steam+0+0000003603.json
# topics/steam/partition=0/steam+0+0000003604.json
# topics/steam/partition=0/steam+0+0000003605.json
# topics/steam/partition=0/steam+0+0000003606.json
# topics/steam/partition=0/steam+0+0000003607.json
# topics/steam/partition=0/steam+0+0000003608.json
# topics/steam/partition=0/steam+0+0000003609.json
# topics/steam/partition=0/steam+0+0000003610.json
# topics/steam/partition=0/steam+0+0000003611.json
# topics/steam/partition=0/steam+0+0000003612.json
# topics/steam/partition=0/steam+0+0000003613.json
# topics/steam/partition=0/steam+0+0000003614.json
# topics/steam/partition=0/steam+0+0000003615.json
# topics/steam/partition=0/steam+0+0000003616.json
# topics/steam/partition=0/steam+0+0000003617.json
# topics/steam/partition=0/steam+0+0000003618.json
# topics/steam/partition=0/steam+0+0000003619.json
# topics/steam/partition=0/steam+0+0000003620.json
# topics/steam/partition=0/steam+0+0000003621.json
# topics/steam/partition=0/steam+0+0000003622.json
# topics/steam/partition=0/steam+0+0000003623.json
# topics/steam/partition=0/steam+0+0000003624.json
# topics/steam/partition=0/steam+0+0000003625.json
# topics/steam/partition=0/steam+0+0000003626.json
# topics/steam/partition=0/steam+0+0000003627.json
# topics/steam/partition=0/steam+0+0000003628.json
# topics/steam/partition=0/steam+0+0000003629.json
# topics/steam/partition=0/steam+0+0000003630.json
# topics/steam/partition=0/steam+0+0000003631.json
# topics/steam/partition=0/steam+0+0000003632.json
# topics/steam/partition=0/steam+0+0000003633.json
# topics/steam/partition=0/steam+0+0000003634.json
# topics/steam/partition=0/steam+0+0000003635.json
# topics/steam/partition=0/steam+0+0000003636.json
# topics/steam/partition=0/steam+0+0000003637.json
# topics/steam/partition=0/steam+0+0000003638.json
# topics/steam/partition=0/steam+0+0000003639.json
# topics/steam/partition=0/steam+0+0000003640.json
# topics/steam/partition=0/steam+0+0000003641.json
# topics/steam/partition=0/steam+0+0000003642.json
# topics/steam/partition=0/steam+0+0000003643.json
# topics/steam/partition=0/steam+0+0000003644.json
# topics/steam/partition=0/steam+0+0000003645.json
# topics/steam/partition=0/steam+0+0000003646.json
# topics/steam/partition=0/steam+0+0000003647.json
# topics/steam/partition=0/steam+0+0000003648.json
# topics/steam/partition=0/steam+0+0000003649.json
# topics/steam/partition=0/steam+0+0000003650.json
# topics/steam/partition=0/steam+0+0000003651.json
# topics/steam/partition=0/steam+0+0000003652.json
# topics/steam/partition=0/steam+0+0000003653.json
# topics/steam/partition=0/steam+0+0000003654.json
# topics/steam/partition=0/steam+0+0000003655.json
# topics/steam/partition=0/steam+0+0000003656.json
# topics/steam/partition=0/steam+0+0000003657.json
# topics/steam/partition=0/steam+0+0000003658.json
# topics/steam/partition=0/steam+0+0000003659.json
# topics/steam/partition=0/steam+0+0000003660.json
# topics/steam/partition=0/steam+0+0000003661.json
# topics/steam/partition=0/steam+0+0000003662.json
# topics/steam/partition=0/steam+0+0000003663.json
# topics/steam/partition=0/steam+0+0000003664.json
# topics/steam/partition=0/steam+0+0000003665.json
# topics/steam/partition=0/steam+0+0000003666.json
# topics/steam/partition=0/steam+0+0000003667.json
# topics/steam/partition=0/steam+0+0000003668.json
# topics/steam/partition=0/steam+0+0000003669.json
# topics/steam/partition=0/steam+0+0000003670.json
# topics/steam/partition=0/steam+0+0000003671.json
# topics/steam/partition=0/steam+0+0000003672.json
# topics/steam/partition=0/steam+0+0000003673.json
# topics/steam/partition=0/steam+0+0000003674.json
# topics/steam/partition=0/steam+0+0000003675.json
# topics/steam/partition=0/steam+0+0000003676.json
# topics/steam/partition=0/steam+0+0000003677.json
# topics/steam/partition=0/steam+0+0000003678.json
# topics/steam/partition=0/steam+0+0000003679.json
# topics/steam/partition=0/steam+0+0000003680.json
# topics/steam/partition=0/steam+0+0000003681.json
# topics/steam/partition=0/steam+0+0000003682.json
# topics/steam/partition=0/steam+0+0000003683.json
# topics/steam/partition=0/steam+0+0000003684.json
# topics/steam/partition=0/steam+0+0000003685.json
# topics/steam/partition=0/steam+0+0000003686.json
# topics/steam/partition=0/steam+0+0000003687.json
# topics/steam/partition=0/steam+0+0000003688.json
# topics/steam/partition=0/steam+0+0000003689.json
# topics/steam/partition=0/steam+0+0000003690.json
# topics/steam/partition=0/steam+0+0000003691.json
# topics/steam/partition=0/steam+0+0000003692.json
# topics/steam/partition=0/steam+0+0000003693.json
# topics/steam/partition=0/steam+0+0000003694.json
# topics/steam/partition=0/steam+0+0000003695.json
# topics/steam/partition=0/steam+0+0000003696.json
# topics/steam/partition=0/steam+0+0000003697.json
# topics/steam/partition=0/steam+0+0000003698.json
# topics/steam/partition=0/steam+0+0000003699.json
# topics/steam/partition=0/steam+0+0000003700.json
# topics/steam/partition=0/steam+0+0000003701.json
# topics/steam/partition=0/steam+0+0000003702.json
# topics/steam/partition=0/steam+0+0000003703.json
# topics/steam/partition=0/steam+0+0000003704.json
# topics/steam/partition=0/steam+0+0000003705.json
# topics/steam/partition=0/steam+0+0000003706.json
# topics/steam/partition=0/steam+0+0000003707.json
# topics/steam/partition=0/steam+0+0000003708.json
# topics/steam/partition=0/steam+0+0000003709.json
# topics/steam/partition=0/steam+0+0000003710.json
# topics/steam/partition=0/steam+0+0000003711.json
# topics/steam/partition=0/steam+0+0000003712.json
# topics/steam/partition=0/steam+0+0000003713.json
# topics/steam/partition=0/steam+0+0000003714.json
# topics/steam/partition=0/steam+0+0000003715.json
# topics/steam/partition=0/steam+0+0000003716.json
# topics/steam/partition=0/steam+0+0000003717.json
# topics/steam/partition=0/steam+0+0000003718.json
# topics/steam/partition=0/steam+0+0000003719.json
# topics/steam/partition=0/steam+0+0000003720.json
# topics/steam/partition=0/steam+0+0000003721.json
# topics/steam/partition=0/steam+0+0000003722.json
# topics/steam/partition=0/steam+0+0000003723.json
# topics/steam/partition=0/steam+0+0000003724.json
# topics/steam/partition=0/steam+0+0000003725.json
# topics/steam/partition=0/steam+0+0000003726.json
# topics/steam/partition=0/steam+0+0000003727.json
# topics/steam/partition=0/steam+0+0000003728.json
# topics/steam/partition=0/steam+0+0000003729.json
# topics/steam/partition=0/steam+0+0000003730.json
# topics/steam/partition=0/steam+0+0000003731.json
# topics/steam/partition=0/steam+0+0000003732.json
# topics/steam/partition=0/steam+0+0000003733.json
# topics/steam/partition=0/steam+0+0000003734.json
# topics/steam/partition=0/steam+0+0000003735.json
# topics/steam/partition=0/steam+0+0000003736.json
# topics/steam/partition=0/steam+0+0000003737.json
# topics/steam/partition=0/steam+0+0000003738.json
# topics/steam/partition=0/steam+0+0000003739.json
# topics/steam/partition=0/steam+0+0000003740.json
# topics/steam/partition=0/steam+0+0000003741.json
# topics/steam/partition=0/steam+0+0000003742.json
# topics/steam/partition=0/steam+0+0000003743.json
# topics/steam/partition=0/steam+0+0000003744.json
# topics/steam/partition=0/steam+0+0000003745.json
# topics/steam/partition=0/steam+0+0000003746.json

# %%
# Para baixar os objetos
client.fget_object("kafka-bucket", "/topics/steam/partition=0/steam+0+0000000000.json", "teste")

# %%
# Get object information.
result = client.stat_object("kafka-bucket", "/topics/steam/partition=0/steam+0+0000000000.json")
print(
    "last-modified: {0}, size: {1}".format(
        result.last_modified, result.size,
    ),
)
# Out:
# last-modified: 2022-03-10 01:08:30+00:00, size: 1324
